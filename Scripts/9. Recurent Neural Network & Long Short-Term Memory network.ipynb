# %%
import os

import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data Loading

# %%
path = '~/Desktop/CareerFoundry/3.1./'
y = pd.read_csv(os.path.join(path, 'Data/Original/Dataset-Answers-Weather_Prediction_Pleasant_Weather.csv'))
X = pd.read_pickle(os.path.join(path, 'Data/Clean/cleaned_for_keras.pkl'))

# %%
y.drop(columns='DATE', inplace=True)

# %%
X = np.array(X)
y = np.array(y)

# %%
X = X.reshape(-1,15,9)
X.shape, y.shape
# Out:
# ((22950, 15, 9), (22950, 15))

# %% [markdown]
# ## Train/Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,y,random_state = 42
)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (17212, 15, 9) (17212, 15)
# (5738, 15, 9) (5738, 15)

# %% [markdown]
# ## RNN Architecture Design

# %%
model = Sequential()

model.add(
    LSTM(
        units=64,
        input_shape=(15, 9)
    )
)

model.add(Dense(64, activation='relu'))

# Multi-label output
model.add(Dense(15, activation='sigmoid'))

model.summary()

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=30,
    batch_size=16,
    validation_split=0.2,
    verbose=2
)
# Out:
# Epoch 1/30
# 861/861 - 3s - 3ms/step - accuracy: 0.1803 - loss: 0.0943 - val_accuracy: 0.1972 - val_loss: 0.0907
# Epoch 2/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1780 - loss: 0.0915 - val_accuracy: 0.1507 - val_loss: 0.0895
# Epoch 3/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1763 - loss: 0.0889 - val_accuracy: 0.1844 - val_loss: 0.0902
# Epoch 4/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1722 - loss: 0.0846 - val_accuracy: 0.1615 - val_loss: 0.0855
# Epoch 5/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1689 - loss: 0.0818 - val_accuracy: 0.1969 - val_loss: 0.0830
# Epoch 6/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1760 - loss: 0.0796 - val_accuracy: 0.1452 - val_loss: 0.0762
# Epoch 7/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1705 - loss: 0.0774 - val_accuracy: 0.1397 - val_loss: 0.0815
# Epoch 8/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1691 - loss: 0.0760 - val_accuracy: 0.1394 - val_loss: 0.0735
# Epoch 9/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1682 - loss: 0.0728 - val_accuracy: 0.1351 - val_loss: 0.0768
# Epoch 10/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1682 - loss: 0.0714 - val_accuracy: 0.1748 - val_loss: 0.0698
# Epoch 11/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1625 - loss: 0.0691 - val_accuracy: 0.1786 - val_loss: 0.0705
# Epoch 12/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1593 - loss: 0.0675 - val_accuracy: 0.2295 - val_loss: 0.0674
# Epoch 13/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1597 - loss: 0.0654 - val_accuracy: 0.1600 - val_loss: 0.0616
# Epoch 14/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1601 - loss: 0.0648 - val_accuracy: 0.1882 - val_loss: 0.0613
# Epoch 15/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1567 - loss: 0.0619 - val_accuracy: 0.1333 - val_loss: 0.0621
# Epoch 16/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1534 - loss: 0.0598 - val_accuracy: 0.2353 - val_loss: 0.0776
# Epoch 17/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1533 - loss: 0.0583 - val_accuracy: 0.1441 - val_loss: 0.0651
# Epoch 18/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1487 - loss: 0.0560 - val_accuracy: 0.1658 - val_loss: 0.0543
# Epoch 19/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1503 - loss: 0.0543 - val_accuracy: 0.2332 - val_loss: 0.0713
# Epoch 20/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1478 - loss: 0.0535 - val_accuracy: 0.1292 - val_loss: 0.0544
# Epoch 21/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1455 - loss: 0.0516 - val_accuracy: 0.1505 - val_loss: 0.0499
# Epoch 22/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1504 - loss: 0.0492 - val_accuracy: 0.1737 - val_loss: 0.0499
# Epoch 23/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1510 - loss: 0.0486 - val_accuracy: 0.1319 - val_loss: 0.0449
# Epoch 24/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1466 - loss: 0.0467 - val_accuracy: 0.1685 - val_loss: 0.0475
# Epoch 25/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1450 - loss: 0.0459 - val_accuracy: 0.1371 - val_loss: 0.0468
# Epoch 26/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1415 - loss: 0.0445 - val_accuracy: 0.1336 - val_loss: 0.0480
# Epoch 27/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1434 - loss: 0.0437 - val_accuracy: 0.1368 - val_loss: 0.0417
# Epoch 28/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1474 - loss: 0.0420 - val_accuracy: 0.1351 - val_loss: 0.0543
# Epoch 29/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1445 - loss: 0.0402 - val_accuracy: 0.1452 - val_loss: 0.0389
# Epoch 30/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1428 - loss: 0.0390 - val_accuracy: 0.1377 - val_loss: 0.0429

# %%
y_pred = (model.predict(X_test) > 0.5).astype(int)

overall_accuracy = (y_pred == y_test).mean()
station_accuracy = (y_pred == y_test).mean(axis=0)

overall_accuracy, station_accuracy
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (np.float64(0.9822818635993958),
#  array([0.97229   , 0.97629836, 0.9797839 , 0.94928547, 0.95887069,
#         0.98919484, 0.98431509, 0.97960962, 0.97786685, 0.99076333,
#         0.99355176, 0.99268038, 1.        , 0.99459742, 0.99512025]))

# %%
# Define list of stations names

stations = {
0: 'BASEL',
1: 'BELGRADE',
2: 'BUDAPEST',
3: 'DEBILT',
4: 'DUSSELDORF',
5: 'HEATHROW',
6: 'KASSEL',
7: 'LJUBLJANA',
8: 'MAASTRICHT',
9: 'MADRID',
10: 'MUNCHENB',
11: 'OSLO',
12: 'SONNBLICK',
13: 'STOCKHOLM',
14: 'VALENTIA'

}

# %%
def confusion_matrix(y_true, y_pred):
    y_true = pd.Series([stations[y] for y in np.argmax(y_true, axis=1)])
    y_pred = pd.Series([stations[y] for y in np.argmax(y_pred, axis=1)])

    return pd.crosstab(y_true, y_pred, rownames=['True'], colnames=['Pred'])

# %%
print(confusion_matrix(y_test, model.predict(X_test)))
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step
# Pred        BASEL  BELGRADE  BUDAPEST  DEBILT  DUSSELDORF  HEATHROW  KASSEL  \
# True
# BASEL          37       358       154       3         640        50       4
# BELGRADE        0       245        20       1           0        16       2
# BUDAPEST        0         2        25       0           0         9       0
# DEBILT          0         1         0       1           1        12       2
# DUSSELDORF      0         0         0       0           0         2       0
# HEATHROW        0         1         0       0           0        11       0
# KASSEL          0         0         0       0           0         0       1
# LJUBLJANA       0         0         0       0           0         0       0
# MAASTRICHT      0         0         0       0           1         0       0
# MADRID          0         0         0       0           0         0       0
# MUNCHENB        0         0         0       0           0         0       0
# OSLO            0         0         0       0           0         0       0
# STOCKHOLM       0         0         0       0           0         0       0
# VALENTIA        0         0         0       0           0         0       0
#
# Pred        LJUBLJANA  MAASTRICHT  MADRID  MUNCHENB  OSLO  STOCKHOLM  VALENTIA
# True
# BASEL             189          74    1515       522    78         31        27
# BELGRADE           31           7     566       122    51         30         1
# BUDAPEST            4           1     116        26    16         14         1
# DEBILT              0           4      37         5    12          6         1
# DUSSELDORF          1           1      21         2     0          2         0
# HEATHROW            0           0      63         2     5          0         0
# KASSEL              1           0       4         4     1          0         0
# LJUBLJANA          14           0      43         2     1          0         1
# MAASTRICHT          0           4       2         1     1          0         0
# MADRID              0           0     451         2     4          1         0
# MUNCHENB            0           0       0         7     1          0         0
# OSLO                0           0       0         0     5          0         0
# STOCKHOLM           0           0       0         0     0          3         1
# VALENTIA            0           0       0         0     0          0         1

# %% [markdown]
# Low and unstable accuracy suggested underfitting. Increasing the number of LSTM units increases the model’s ability to capture temporal dependencies.

# %% [markdown]
# Adjustments

# %%
model = Sequential()

model.add(
    LSTM(
        units=32,
        input_shape=(15, 9)
    )
)

model.add(Dense(64, activation='relu'))

# Multi-label output
model.add(Dense(15, activation='sigmoid'))

model.summary()
# Out:
# /opt/miniconda3/lib/python3.13/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 32)             │         5,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 15)             │           975 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,463 (33.06 KB)
#  Trainable params: 8,463 (33.06 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=30,
    batch_size=32, ## changed
    validation_split=0.2,
    verbose=2
)
# Out:
# Epoch 1/30
# 431/431 - 2s - 5ms/step - accuracy: 0.0800 - loss: 0.3218 - val_accuracy: 0.0868 - val_loss: 0.2605
# Epoch 2/30
# 431/431 - 1s - 2ms/step - accuracy: 0.1310 - loss: 0.2509 - val_accuracy: 0.1473 - val_loss: 0.2444
# Epoch 3/30
# 431/431 - 1s - 2ms/step - accuracy: 0.1647 - loss: 0.2364 - val_accuracy: 0.2077 - val_loss: 0.2361
# Epoch 4/30
# 431/431 - 1s - 2ms/step - accuracy: 0.1825 - loss: 0.2261 - val_accuracy: 0.1577 - val_loss: 0.2200
# Epoch 5/30
# 431/431 - 1s - 2ms/step - accuracy: 0.1975 - loss: 0.2180 - val_accuracy: 0.1775 - val_loss: 0.2135
# Epoch 6/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2137 - loss: 0.2106 - val_accuracy: 0.2016 - val_loss: 0.2099
# Epoch 7/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2252 - loss: 0.2053 - val_accuracy: 0.2443 - val_loss: 0.2025
# Epoch 8/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2304 - loss: 0.2006 - val_accuracy: 0.2751 - val_loss: 0.1976
# Epoch 9/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2397 - loss: 0.1959 - val_accuracy: 0.2536 - val_loss: 0.1936
# Epoch 10/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2464 - loss: 0.1908 - val_accuracy: 0.2286 - val_loss: 0.1944
# Epoch 11/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2479 - loss: 0.1870 - val_accuracy: 0.2634 - val_loss: 0.1857
# Epoch 12/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2498 - loss: 0.1837 - val_accuracy: 0.2614 - val_loss: 0.1805
# Epoch 13/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2477 - loss: 0.1794 - val_accuracy: 0.2768 - val_loss: 0.1814
# Epoch 14/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2470 - loss: 0.1768 - val_accuracy: 0.3050 - val_loss: 0.1781
# Epoch 15/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2519 - loss: 0.1738 - val_accuracy: 0.2832 - val_loss: 0.1728
# Epoch 16/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2494 - loss: 0.1709 - val_accuracy: 0.2640 - val_loss: 0.1708
# Epoch 17/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2453 - loss: 0.1672 - val_accuracy: 0.2408 - val_loss: 0.1673
# Epoch 18/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2452 - loss: 0.1648 - val_accuracy: 0.2713 - val_loss: 0.1695
# Epoch 19/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2440 - loss: 0.1630 - val_accuracy: 0.2443 - val_loss: 0.1629
# Epoch 20/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2442 - loss: 0.1596 - val_accuracy: 0.2109 - val_loss: 0.1655
# Epoch 21/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2408 - loss: 0.1573 - val_accuracy: 0.2399 - val_loss: 0.1569
# Epoch 22/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2389 - loss: 0.1553 - val_accuracy: 0.1748 - val_loss: 0.1571
# Epoch 23/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2371 - loss: 0.1522 - val_accuracy: 0.2170 - val_loss: 0.1542
# Epoch 24/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2376 - loss: 0.1498 - val_accuracy: 0.2663 - val_loss: 0.1496
# Epoch 25/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2315 - loss: 0.1469 - val_accuracy: 0.2158 - val_loss: 0.1512
# Epoch 26/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2296 - loss: 0.1443 - val_accuracy: 0.2399 - val_loss: 0.1462
# Epoch 27/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2272 - loss: 0.1414 - val_accuracy: 0.2286 - val_loss: 0.1448
# Epoch 28/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2247 - loss: 0.1382 - val_accuracy: 0.2544 - val_loss: 0.1404
# Epoch 29/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2209 - loss: 0.1358 - val_accuracy: 0.2190 - val_loss: 0.1357
# Epoch 30/30
# 431/431 - 1s - 2ms/step - accuracy: 0.2244 - loss: 0.1333 - val_accuracy: 0.2196 - val_loss: 0.1366

# %%
y_pred = (model.predict(X_test) > 0.5).astype(int)

overall_accuracy = (y_pred == y_test).mean()
station_accuracy = (y_pred == y_test).mean(axis=0)

overall_accuracy, station_accuracy
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (np.float64(0.9400604159405135),
#  array([0.95834786, 0.92366678, 0.89874521, 0.92418961, 0.93342628,
#         0.87155803, 0.92331823, 0.90275357, 0.93429766, 0.94109446,
#         0.96653886, 0.97385849, 1.        , 0.96950157, 0.97960962]))

# %%
print(confusion_matrix(y_test, model.predict(X_test)))
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step
# Pred        BASEL  BELGRADE  BUDAPEST  DEBILT  DUSSELDORF  HEATHROW  KASSEL  \
# True
# BASEL         356      1735        47       0         143        91       2
# BELGRADE        6       468         4       1          24         0       0
# BUDAPEST        4        33         3       0           8         1       0
# DEBILT          0         0         0       0          10         0       0
# DUSSELDORF      0         0         0       0           2         0       0
# HEATHROW        2         1         0       0           1         7       0
# KASSEL          1         0         0       0           1         0       0
# LJUBLJANA       2         4         2       0           0         1       0
# MAASTRICHT      0         0         1       0           0         1       0
# MADRID          3         1         1       0           0         2       0
# MUNCHENB        0         0         0       0           0         0       0
# OSLO            0         0         0       0           0         0       0
# STOCKHOLM       0         0         0       0           0         0       0
# VALENTIA        0         0         0       0           0         0       0
#
# Pred        LJUBLJANA  MAASTRICHT  MADRID  MUNCHENB  OSLO  STOCKHOLM  VALENTIA
# True
# BASEL              21           4     717       244    66         96       160
# BELGRADE            5           0     401        36    49         95         3
# BUDAPEST            0           0     118         6    19         20         2
# DEBILT              0           0      34         2    12         20         4
# DUSSELDORF          0           1      17         1     4          4         0
# HEATHROW            0           0      60         0     5          5         1
# KASSEL              0           0       2         3     1          3         0
# LJUBLJANA           2           0      43         2     3          2         0
# MAASTRICHT          0           0       5         1     1          0         0
# MADRID              0           0     440         0     4          7         0
# MUNCHENB            0           0       2         5     1          0         0
# OSLO                0           0       0         0     5          0         0
# STOCKHOLM           0           0       0         0     1          3         0
# VALENTIA            0           0       0         0     0          0         1

# %% [markdown]
# Adjustments

# %%
model = Sequential()

model.add(
    LSTM(
        units=32, ## changed
        input_shape=(15, 9)
    )
)

model.add(Dense(64, activation='relu'))

# Multi-label output
model.add(Dense(15, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 32)             │         5,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 15)             │           975 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,463 (33.06 KB)
#  Trainable params: 8,463 (33.06 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# The LSTM model consists of a single recurrent layer followed by two dense layers.
# Compared to the CNN architecture, the LSTM contains fewer trainable parameters,
# reflecting a more compact model design.
#
# The LSTM layer processes the sequence of weather stations as ordered inputs,
# producing a fixed-length representation that is subsequently mapped to
# station-level pleasant weather predictions via sigmoid-activated output units.

# %% [markdown]
# Compile and Run

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=30,
    batch_size=16, ## chnaged
    validation_split=0.2,
    verbose=2
)
# Out:
# Epoch 1/30
# 861/861 - 3s - 4ms/step - accuracy: 0.0905 - loss: 0.2903 - val_accuracy: 0.1281 - val_loss: 0.2484
# Epoch 2/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1495 - loss: 0.2426 - val_accuracy: 0.1690 - val_loss: 0.2310
# Epoch 3/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1901 - loss: 0.2269 - val_accuracy: 0.1775 - val_loss: 0.2200
# Epoch 4/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2169 - loss: 0.2169 - val_accuracy: 0.1992 - val_loss: 0.2101
# Epoch 5/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2527 - loss: 0.2071 - val_accuracy: 0.1807 - val_loss: 0.2032
# Epoch 6/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2755 - loss: 0.2000 - val_accuracy: 0.2248 - val_loss: 0.2024
# Epoch 7/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2824 - loss: 0.1933 - val_accuracy: 0.2902 - val_loss: 0.1892
# Epoch 8/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2847 - loss: 0.1863 - val_accuracy: 0.3230 - val_loss: 0.1850
# Epoch 9/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2849 - loss: 0.1805 - val_accuracy: 0.3413 - val_loss: 0.1867
# Epoch 10/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2835 - loss: 0.1746 - val_accuracy: 0.2489 - val_loss: 0.1724
# Epoch 11/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2801 - loss: 0.1683 - val_accuracy: 0.2202 - val_loss: 0.1657
# Epoch 12/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2657 - loss: 0.1627 - val_accuracy: 0.2353 - val_loss: 0.1586
# Epoch 13/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2619 - loss: 0.1568 - val_accuracy: 0.2835 - val_loss: 0.1557
# Epoch 14/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2577 - loss: 0.1516 - val_accuracy: 0.1998 - val_loss: 0.1491
# Epoch 15/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2489 - loss: 0.1466 - val_accuracy: 0.2103 - val_loss: 0.1457
# Epoch 16/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2401 - loss: 0.1421 - val_accuracy: 0.2524 - val_loss: 0.1398
# Epoch 17/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2373 - loss: 0.1371 - val_accuracy: 0.2739 - val_loss: 0.1371
# Epoch 18/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2349 - loss: 0.1327 - val_accuracy: 0.1798 - val_loss: 0.1315
# Epoch 19/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2247 - loss: 0.1292 - val_accuracy: 0.2042 - val_loss: 0.1262
# Epoch 20/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2156 - loss: 0.1255 - val_accuracy: 0.1626 - val_loss: 0.1267
# Epoch 21/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2116 - loss: 0.1217 - val_accuracy: 0.2585 - val_loss: 0.1209
# Epoch 22/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2072 - loss: 0.1192 - val_accuracy: 0.1446 - val_loss: 0.1221
# Epoch 23/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1946 - loss: 0.1171 - val_accuracy: 0.2483 - val_loss: 0.1179
# Epoch 24/30
# 861/861 - 2s - 2ms/step - accuracy: 0.2026 - loss: 0.1141 - val_accuracy: 0.2132 - val_loss: 0.1120
# Epoch 25/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1925 - loss: 0.1112 - val_accuracy: 0.1783 - val_loss: 0.1154
# Epoch 26/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1975 - loss: 0.1097 - val_accuracy: 0.2207 - val_loss: 0.1073
# Epoch 27/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1835 - loss: 0.1068 - val_accuracy: 0.1653 - val_loss: 0.1071
# Epoch 28/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1889 - loss: 0.1040 - val_accuracy: 0.2509 - val_loss: 0.1036
# Epoch 29/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1837 - loss: 0.1021 - val_accuracy: 0.2297 - val_loss: 0.1148
# Epoch 30/30
# 861/861 - 2s - 2ms/step - accuracy: 0.1844 - loss: 0.0979 - val_accuracy: 0.1690 - val_loss: 0.1034

# %% [markdown]
# The training process exhibits moderate instability, with accuracy peaking early
# and subsequently declining despite continued loss reduction.
#
# This behavior suggests that the LSTM struggles to extract consistent predictive
# patterns from the imposed station sequence. While the model continues to improve
# probability calibration (as reflected by decreasing loss), these improvements do
# not consistently translate into better thresholded predictions.

# %%
y_pred = (model.predict(X_test) > 0.5).astype(int)

overall_accuracy = (y_pred == y_test).mean()
station_accuracy = (y_pred == y_test).mean(axis=0)

overall_accuracy, station_accuracy
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (np.float64(0.9554548623213663),
#  array([0.97385849, 0.952771  , 0.93900314, 0.93116068, 0.93900314,
#         0.87486929, 0.92471244, 0.94701987, 0.93534333, 0.97664692,
#         0.98640641, 0.98466365, 1.        , 0.97804113, 0.98832346]))

# %% [markdown]
# overall_accuracy = 0.9554548623213663
# The overall label-wise accuracy of the LSTM model is high; however, this result is
# strongly influenced by the prevalence of negative labels in the dataset.
#
# Compared to the CNN, the LSTM achieves slightly lower overall accuracy, indicating
# reduced effectiveness in distinguishing station-level pleasant weather outcomes.

# %% [markdown]
# Station-level accuracy varies more substantially for the LSTM model than for the
# CNN. This uneven performance suggests that the sequential modeling assumption
# does not benefit all stations equally and may introduce noise rather than useful
# structure for certain locations.

# %%
print(confusion_matrix(y_test, model.predict(X_test)))
# Out:
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# Pred        BASEL  BELGRADE  BUDAPEST  DEBILT  DUSSELDORF  HEATHROW  KASSEL  \
# True
# BASEL         184       492       327       0         177       417      11
# BELGRADE        3       282         7       0           9         0       0
# BUDAPEST        1         9        14       0           5         2       1
# DEBILT          0         1         0       1           4         0       1
# DUSSELDORF      0         0         0       0           3         0       0
# HEATHROW        0         1         0       0           4         3       0
# KASSEL          1         0         0       0           0         0       2
# LJUBLJANA       0         1         1       0           0         0       0
# MAASTRICHT      0         0         0       0           1         2       0
# MADRID          0         0         0       0           0         0       0
# MUNCHENB        0         0         0       0           0         0       0
# OSLO            0         0         0       0           0         0       0
# STOCKHOLM       0         0         0       0           0         0       0
# VALENTIA        0         0         0       0           0         0       0
#
# Pred        LJUBLJANA  MAASTRICHT  MADRID  MUNCHENB  OSLO  STOCKHOLM  VALENTIA
# True
# BASEL             201          12    1266       446    19        109        21
# BELGRADE           66           1     512        79     7        120         6
# BUDAPEST            8           0     124        13     4         30         3
# DEBILT              0           1      38         7     1         26         2
# DUSSELDORF          1           0      20         1     0          4         0
# HEATHROW            0           0      65         0     1          7         1
# KASSEL              0           0       2         3     0          3         0
# LJUBLJANA          10           0      43         1     1          3         1
# MAASTRICHT          0           0       4         1     1          0         0
# MADRID              0           0     453         0     0          4         1
# MUNCHENB            0           0       1         6     1          0         0
# OSLO                0           0       0         0     5          0         0
# STOCKHOLM           0           0       0         0     0          4         0
# VALENTIA            0           0       0         0     0          0         1

# %% [markdown]
# The confusion matrix was generated by applying an argmax operation across station
# outputs, which implicitly converts the multi-label problem into a multi-class
# setting. As a result, the matrix does not represent true classification errors
# and should be interpreted with caution.
#
# The dominance of certain stations in the matrix reflects relative signal strength
# rather than meaningful station-level confusion. For this reason, label-wise
# accuracy remains a more appropriate evaluation metric for this task.
